# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Вказуємо абсолютний шлях до файлу CSV
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)
df
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                  0.5                          0.5               400
# 1     меньше 3 месяцев             меньше 3 месяцев               430
# 2                    4                            1              2500
# 3                    5                            4              2000
# 4       10 и более лет                          0.5              4500
# ...                ...                          ...               ...
# 8699                 1             меньше 3 месяцев               700
# 8700               0.5                          0.5               400
# 8701                 1                          0.5               800
# 8702                 6                            4              2600
# 8703                 7                            2              5000
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                    0  Харьков       до 10 человек  ...
# 1                                  130  Харьков  свыше 1000 человек  ...
# 2                                  800     Киев     до 1000 человек  ...
# 3                                  400   Одесса      до 200 человек  ...
# 4                                  500   Другой       до 10 человек  ...
# ...                                ...      ...                 ...  ...
# 8699                               700   Одесса       до 50 человек  ...
# 8700                               120     Киев       до 50 человек  ...
# 8701                               500    Львов       до 10 человек  ...
# 8702                                 0    Днепр  свыше 1000 человек  ...
# 8703                               800   Одесса     до 1000 человек  ...
#
#      Еще.студент Уровень.английского                    Предметная.область  \
# 0           True       ниже среднего                         iOS,eCommerce
# 1           True       выше среднего                        Веб-разработка
# 2          False             средний  Веб-разработка,Корпоративные системы
# 3          False       ниже среднего   Desktop Applications,Веб-разработка
# 4          False             средний   Desktop Applications,Веб-разработка
# ...          ...                 ...                                   ...
# 8699       False             средний          Android,Desktop Applications
# 8700       False       ниже среднего                             eCommerce
# 8701       False       выше среднего  Веб-разработка,Корпоративные системы
# 8702       False         продвинутый                       Финансы и банки
# 8703       False       выше среднего                        Веб-разработка
#
#           Дата.заполнения                                         User.Agent  \
# 0     12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1     12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2     12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3     12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4     12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# ...                   ...                                                ...
# 8699  12/07/2017 15:45:24  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8700  12/07/2017 17:00:06  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8701  12/07/2017 17:32:26  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8702  12/07/2017 18:14:59  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 8703  12/07/2017 21:28:57  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
#
#        exp current_job_exp salary Валюта  cls
# 0      0.5             0.5    400    NaN   QA
# 1      0.0             0.0    430    NaN   QA
# 2      4.0             1.0   2500    NaN  DEV
# 3      5.0             4.0   2000    NaN  DEV
# 4     10.0             0.5   4500    NaN  DEV
# ...    ...             ...    ...    ...  ...
# 8699   1.0             0.0    700    NaN   QA
# 8700   0.5             0.5    400    NaN  NaN
# 8701   1.0             0.5    800    NaN  DEV
# 8702   6.0             4.0   2600    NaN   PM
# 8703   7.0             2.0   5000    NaN  DEV
#
# [8704 rows x 25 columns]

# %%
# Виводимо перші 5 рядків таблиці
df_head = df.head(5)
df_head
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
# 3                               400   Одесса      до 200 человек  ...
# 4                               500   Другой       до 10 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# 1        True       выше среднего                        Веб-разработка
# 2       False             средний  Веб-разработка,Корпоративные системы
# 3       False       ниже среднего   Desktop Applications,Веб-разработка
# 4       False             средний   Desktop Applications,Веб-разработка
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3  12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4  12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
#
#     exp current_job_exp salary Валюта  cls
# 0   0.5             0.5    400    NaN   QA
# 1   0.0             0.0    430    NaN   QA
# 2   4.0             1.0   2500    NaN  DEV
# 3   5.0             4.0   2000    NaN  DEV
# 4  10.0             0.5   4500    NaN  DEV
#
# [5 rows x 25 columns]

# %%
#Визначте розмір таблиці за допомогою методу shape
shape = df.shape
print("Кількість рядків:", shape[0])
print("Кількість стовпців:", shape[1])
# Out:
# Кількість рядків: 8704
# Кількість стовпців: 25

# %%
#Визначте типи всіх стовпців за допомогою dataframe.dtypes
column_types = df.dtypes
print(column_types)
# Out:
# Кількість стовпців: N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %%
# Підрахунок кількості пропусків у кожній колонці
missing_counts = df.isnull().sum()

# Підрахунок загальної кількості рядків у таблиці
total_rows = len(df)

# Розрахунок частки пропусків у кожній колонці
missing_fraction = missing_counts / total_rows

print("Частка пропусків в кожній колонці:")
print(missing_fraction)
# Out:
# Частка пропусків в кожній колонці:
# N                                   0.000000
# Должность                           0.000000
# Язык.программирования               0.442325
# Специализация                       0.829389
# Общий.опыт.работы                   0.000000
# Опыт.работы.на.текущем.месте        0.000000
# Зарплата.в.месяц                    0.000000
# Изменение.зарплаты.за.12.месяцев    0.000000
# Город                               0.000000
# Размер.компании                     0.000000
# Тип.компании                        0.000000
# Пол                                 0.000000
# Возраст                             0.000000
# Образование                         0.000000
# Университет                         0.041131
# Еще.студент                         0.000000
# Уровень.английского                 0.000000
# Предметная.область                  0.025620
# Дата.заполнения                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# current_job_exp                     0.000000
# salary                              0.000000
# Валюта                              0.998851
# cls                                 0.180836
# dtype: float64

# %%
#Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Визначаємо список індексів стовпців, які не мають пропусків, крім "Мова програмування"
columns_to_keep = ["Язык.программирования"]

# Додаємо інші стовпці, які не мають пропусків, до списку columns_to_keep
for column in df.columns:
    if column != "Язык.программирования" and not df[column].isnull().any():
        columns_to_keep.append(column)

# Вибираємо лише стовпці, які ми зберігаємо
df_cleaned = df[columns_to_keep]

df_cleaned
# Out:
#      Язык.программирования     N                 Должность Общий.опыт.работы  \
# 0                      NaN     1        Junior QA engineer               0.5
# 1                      NaN     2        Junior QA engineer  меньше 3 месяцев
# 2                  C#/.NET     3         Software Engineer                 4
# 3               JavaScript     4         Software Engineer                 5
# 4               JavaScript     5  Senior Software Engineer    10 и более лет
# ...                    ...   ...                       ...               ...
# 8699                   NaN  8700               QA engineer                 1
# 8700                   NaN  8701                 Marketing               0.5
# 8701            Ruby/Rails  8702  Junior Software Engineer                 1
# 8702                   NaN  8703                 Team lead                 6
# 8703                  Java  8704  Senior Software Engineer                 7
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                             0.5               400
# 1                меньше 3 месяцев               430
# 2                               1              2500
# 3                               4              2000
# 4                             0.5              4500
# ...                           ...               ...
# 8699             меньше 3 месяцев               700
# 8700                          0.5               400
# 8701                          0.5               800
# 8702                            4              2600
# 8703                            2              5000
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# 0                                    0  Харьков       до 10 человек
# 1                                  130  Харьков  свыше 1000 человек
# 2                                  800     Киев     до 1000 человек
# 3                                  400   Одесса      до 200 человек
# 4                                  500   Другой       до 10 человек
# ...                                ...      ...                 ...
# 8699                               700   Одесса       до 50 человек
# 8700                               120     Киев       до 50 человек
# 8701                               500    Львов       до 10 человек
# 8702                                 0    Днепр  свыше 1000 человек
# 8703                               800   Одесса     до 1000 человек
#
#          Тип.компании      Пол  Возраст           Образование  Еще.студент  \
# 0      Аутсорсинговая  женский       20  Незаконченное высшее         True
# 1      Аутсорсинговая  женский       21  Незаконченное высшее         True
# 2      Аутсорсинговая  мужской       26                Высшее        False
# 3         Продуктовая  мужской       30               Среднее        False
# 4         Продуктовая  мужской       30    Техникум / Колледж        False
# ...               ...      ...      ...                   ...          ...
# 8699   Аутсорсинговая  мужской       23                Высшее        False
# 8700      Продуктовая  женский       22                Высшее        False
# 8701  Аутстаффинговая  мужской       30  Незаконченное высшее        False
# 8702   Аутсорсинговая  мужской       34                Высшее        False
# 8703      Продуктовая  мужской       28                Высшее        False
#
#      Уровень.английского      Дата.заполнения  \
# 0          ниже среднего  12/06/2017 12:38:08
# 1          выше среднего  12/06/2017 12:42:51
# 2                средний  12/06/2017 13:02:47
# 3          ниже среднего  12/06/2017 13:03:01
# 4                средний  12/06/2017 13:03:47
# ...                  ...                  ...
# 8699             средний  12/07/2017 15:45:24
# 8700       ниже среднего  12/07/2017 17:00:06
# 8701       выше среднего  12/07/2017 17:32:26
# 8702         продвинутый  12/07/2017 18:14:59
# 8703       выше среднего  12/07/2017 21:28:57
#
#                                              User.Agent   exp  \
# 0     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5
# 1     Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0
# 3     Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0
# ...                                                 ...   ...
# 8699  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   1.0
# 8700  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5
# 8701  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# 8702  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...   6.0
# 8703  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...   7.0
#
#       current_job_exp  salary
# 0                 0.5     400
# 1                 0.0     430
# 2                 1.0    2500
# 3                 4.0    2000
# 4                 0.5    4500
# ...               ...     ...
# 8699              0.0     700
# 8700              0.5     400
# 8701              0.5     800
# 8702              4.0    2600
# 8703              2.0    5000
#
# [8704 rows x 20 columns]

# %%
#яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Вибираємо лише стовпець "Мова.програмування"
df_cleaned = df[["Язык.программирования"]]

# Визначаємо частку пропусків в кожному стовпці
missing_fraction = df_cleaned.isnull().mean()

print("Частка пропусків в кожній колонці:")
print(missing_fraction)
# Out:
# Частка пропусків в кожній колонці:
# Язык.программирования    0.442325
# dtype: float64

# %%
#Видаліть усі рядки у вихідній таблиці за допомогою методу dropna
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Видаляємо рядки з пропусками
df_cleaned = df.dropna()

print(df_cleaned)
# Out:
# Empty DataFrame
# Columns: [N, Должность, Язык.программирования, Специализация, Общий.опыт.работы, Опыт.работы.на.текущем.месте, Зарплата.в.месяц, Изменение.зарплаты.за.12.месяцев, Город, Размер.компании, Тип.компании, Пол, Возраст, Образование, Университет, Еще.студент, Уровень.английского, Предметная.область, Дата.заполнения, User.Agent, exp, current_job_exp, salary, Валюта, cls]
# Index: []
#
# [0 rows x 25 columns]

# %%
# розмір нової таблиці
shape_cleaned = df_cleaned.shape

# Виводимо результат
print("Розмір нової таблиці:")
print("Кількість рядків:", shape_cleaned[0])
print("Кількість стовпців:", shape_cleaned[1])
# Out:
# Розмір нової таблиці:
# Кількість рядків: 0
# Кількість стовпців: 25

# %%
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Створюємо нову таблицю, де "Язык.программирования" рівна "Python"
python_data = df[df["Язык.программирования"] == "Python"]

python_data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 12      13         Software Engineer                Python           NaN
# 68      69         Software Engineer                Python           NaN
# 87      88  Junior Software Engineer                Python           NaN
# 114    115  Junior Software Engineer                Python           NaN
# 143    144  Junior Software Engineer                Python           NaN
# ...    ...                       ...                   ...           ...
# 8546  8547         Software Engineer                Python           NaN
# 8625  8626         Software Engineer                Python           NaN
# 8635  8636  Senior Software Engineer                Python           NaN
# 8673  8674  Junior Software Engineer                Python           NaN
# 8695  8696         Software Engineer                Python           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 12                   1             меньше 3 месяцев               800
# 68                 1.5                          0.5               900
# 87                 0.5                          0.5               600
# 114                1.5                          0.5               685
# 143                  1                            1               750
# ...                ...                          ...               ...
# 8546                 5                            1              2000
# 8625                 4                            1              1750
# 8635    10 и более лет             меньше 3 месяцев              4000
# 8673               0.5                          0.5               350
# 8695                 1                          0.5              1500
#
#       Изменение.зарплаты.за.12.месяцев      Город     Размер.компании  ...  \
# 12                                 200       Киев       до 50 человек  ...
# 68                                 900       Киев       до 10 человек  ...
# 87                                   0       Киев       до 10 человек  ...
# 114                                250       Киев     до 1000 человек  ...
# 143                                250       Киев       до 10 человек  ...
# ...                                ...        ...                 ...  ...
# 8546                               800  Запорожье       до 50 человек  ...
# 8625                                 0       Киев  свыше 1000 человек  ...
# 8635                              1300   Удаленно       до 10 человек  ...
# 8673                                50       Киев       до 50 человек  ...
# 8695                              1000       Киев       до 10 человек  ...
#
#      Еще.студент Уровень.английского         Предметная.область  \
# 12         False       ниже среднего      Веб-разработка,Другое
# 68          True       выше среднего             Веб-разработка
# 87          True       выше среднего   Веб-разработка,eCommerce
# 114        False             средний                     Другое
# 143         True       выше среднего             Веб-разработка
# ...          ...                 ...                        ...
# 8546       False             средний             Веб-разработка
# 8625       False             средний             Веб-разработка
# 8635       False       выше среднего             Веб-разработка
# 8673       False             средний             Веб-разработка
# 8695       False             средний  Финансы и банки,eCommerce
#
#           Дата.заполнения                                         User.Agent  \
# 12    12/06/2017 13:05:54  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 68    12/06/2017 13:11:17  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 87    12/06/2017 13:12:25  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 114   12/06/2017 13:14:52  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 143   12/06/2017 13:19:10  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# ...                   ...                                                ...
# 8546  10/07/2017 14:11:26  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
# 8625  11/07/2017 16:15:40  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8635  11/07/2017 17:51:36  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8673  12/07/2017 09:37:16  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8695  12/07/2017 14:39:21  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#        exp current_job_exp salary Валюта  cls
# 12     1.0             0.0    800    NaN  DEV
# 68     1.5             0.5    900    NaN  DEV
# 87     0.5             0.5    600    NaN  DEV
# 114    1.5             0.5    685    NaN  DEV
# 143    1.0             1.0    750    NaN  DEV
# ...    ...             ...    ...    ...  ...
# 8546   5.0             1.0   2000    NaN  DEV
# 8625   4.0             1.0   1750    NaN  DEV
# 8635  10.0             0.0   4000    NaN  DEV
# 8673   0.5             0.5    350    NaN  DEV
# 8695   1.0             0.5   1500    NaN  DEV
#
# [207 rows x 25 columns]

# %%
# Визначаємо розмір таблиці python_data
shape_python_data = python_data.shape

print("Розмір таблиці python_data:")
print("Кількість рядків:", shape_python_data[0])
print("Кількість стовпців:", shape_python_data[1])
# Out:
# Розмір таблиці python_data:
# Кількість рядків: 207
# Кількість стовпців: 25

# %%
#Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Групуємо дані за стовпцем "Посада"
grouped_data = df.groupby("Должность")

for position, group in grouped_data:
    print(f"Посада: {position}")
    print(group)
# Out:
# Посада: Business analyst
#          N         Должность Язык.программирования Специализация  \
# 136    137  Business analyst                   NaN           NaN
# 226    227  Business analyst                   NaN           NaN
# 254    255  Business analyst                   NaN           NaN
# 297    298  Business analyst                   NaN           NaN
# 338    339  Business analyst                   NaN           NaN
# ...    ...               ...                   ...           ...
# 8373  8374  Business analyst                   NaN           NaN
# 8484  8485  Business analyst                   NaN           NaN
# 8562  8563  Business analyst                   NaN           NaN
# 8587  8588  Business analyst                   NaN           NaN
# 8649  8650  Business analyst                   NaN           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 136                  7                         0.25              2500
# 226                  3             меньше 3 месяцев              1500
# 254                  3                            2              2500
# 297                  4                          1.5              2500
# 338                  6                            1              2375
# ...                ...                          ...               ...
# 8373                 9                          1.5              1362
# 8484                 2                            2              1000
# 8562               1.5                          1.5               750
# 8587                 1                            1               800
# 8649                 2             меньше 3 месяцев               700
#
#       Изменение.зарплаты.за.12.месяцев     Город     Размер.компании  ...  \
# 136                                800      Киев      до 200 человек  ...
# 226                                  0    Одесса     до 1000 человек  ...
# 254                                700    Другой      до 200 человек  ...
# 297                                  0      Киев  свыше 1000 человек  ...
# 338                                  0      Киев  свыше 1000 человек  ...
# ...                                ...       ...                 ...  ...
# 8373                                 0      Киев      до 200 человек  ...
# 8484                               200  Удаленно       до 10 человек  ...
# 8562                                50      Киев      до 200 человек  ...
# 8587                                 0      Киев       до 10 человек  ...
# 8649                                 0      Киев      до 200 человек  ...
#
#      Еще.студент Уровень.английского                     Предметная.область  \
# 136        False         продвинутый   Веб-разработка,Корпоративные системы
# 226        False       выше среднего                         Веб-разработка
# 254        False         продвинутый                        Финансы и банки
# 297        False       выше среднего           Корпоративные системы,Другое
# 338        False       выше среднего                                    NaN
# ...          ...                 ...                                    ...
# 8373       False             средний                        Финансы и банки
# 8484       False       выше среднего                        Финансы и банки
# 8562       False       ниже среднего  Финансы и банки,Корпоративные системы
# 8587       False       выше среднего                                    NaN
# 8649       False             средний                              eCommerce
#
#           Дата.заполнения                                         User.Agent  \
# 136   12/06/2017 13:17:53  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 226   12/06/2017 13:34:16  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 254   12/06/2017 13:39:12  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 297   12/06/2017 13:45:50  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 338   12/06/2017 13:52:16  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# ...                   ...                                                ...
# 8373  07/07/2017 18:18:34  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
# 8484  09/07/2017 13:49:40  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 8562  10/07/2017 16:47:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8587  11/07/2017 09:09:25  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 8649  11/07/2017 22:24:17  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#       exp current_job_exp salary Валюта  cls
# 136   7.0            0.25   2500    NaN  NaN
# 226   3.0            0.00   1500    NaN  NaN
# 254   3.0            2.00   2500    NaN  NaN
# 297   4.0            1.50   2500    NaN  NaN
# 338   6.0            1.00   2375    NaN  NaN
# ...   ...             ...    ...    ...  ...
# 8373  9.0            1.50   1362    NaN  NaN
# 8484  2.0            2.00   1000    NaN  NaN
# 8562  1.5            1.50    750    NaN  NaN
# 8587  1.0            1.00    800    NaN  NaN
# 8649  2.0            0.00    700    NaN  NaN
#
# [150 rows x 25 columns]
# Посада: DBA
#          N Должность Язык.программирования Специализация Общий.опыт.работы  \
# 50      51       DBA                   NaN           NaN                 8
# 351    352       DBA                   NaN           NaN                 4
# 1310  1311       DBA                   NaN           NaN                 2
# 1537  1538       DBA                   NaN           NaN    10 и более лет
# 2295  2296       DBA                   NaN           NaN                 3
# 2310  2311       DBA                   NaN           NaN    10 и более лет
# 2345  2346       DBA                   NaN           NaN                 5
# 2856  2857       DBA                   NaN           NaN                 2
# 2896  2897       DBA                   NaN           NaN    10 и более лет
# 3043  3044       DBA                   NaN           NaN                 2
# 3552  3553       DBA                   NaN           NaN               0.5
# 3566  3567       DBA                   NaN           NaN                 3
# 3598  3599       DBA                   NaN           NaN               1.5
# 4300  4301       DBA                   NaN           NaN                 8
# 5012  5013       DBA                   NaN           NaN    10 и более лет
# 5438  5439       DBA                   NaN           NaN                 5
# 5671  5672       DBA                   NaN           NaN    10 и более лет
# 6153  6154       DBA                   NaN           NaN                 2
# 6168  6169       DBA                   NaN           NaN                 8
# 6385  6386       DBA                   NaN           NaN    10 и более лет
# 7333  7334       DBA                   NaN           NaN                 6
# 7539  7540       DBA                   NaN           NaN                 7
# 7799  7800       DBA                   NaN           NaN                 7
# 8090  8091       DBA                   NaN           NaN               0.5
# 8169  8170       DBA                   NaN           NaN    10 и более лет
# 8529  8530       DBA                   NaN           NaN               1.5
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 50                            0.5              3500
# 351                             1              2000
# 1310                            2               510
# 1537                          0.5              6000
# 2295                            3              1200
# 2310                            7              1300
# 2345                          1.5              3000
# 2856                            2               615
# 2896               10 и более лет              1300
# 3043                          0.5               600
# 3552                          0.5               700
# 3566             меньше 3 месяцев               900
# 3598             меньше 3 месяцев               700
# 4300                            2              2000
# 5012                            4               920
# 5438                          1.5              2090
# 5671                            2              1200
# 6153                          0.5              1400
# 6168                            2              2000
# 6385                            5               500
# 7333                            6               570
# 7539                            3              2150
# 7799                            2              2200
# 8090             меньше 3 месяцев               380
# 8169                          1.5              2750
# 8529                          1.5              2500
#
#       Изменение.зарплаты.за.12.месяцев     Город     Размер.компании  ...  \
# 50                                 150      Киев       до 50 человек  ...
# 351                                  0      Киев  свыше 1000 человек  ...
# 1310                               125      Киев  свыше 1000 человек  ...
# 1537                               500    Другой       до 10 человек  ...
# 2295                               200     Днепр       до 50 человек  ...
# 2310                               100      Киев     до 1000 человек  ...
# 2345                              1000      Киев      до 200 человек  ...
# 2856                               230      Киев       до 50 человек  ...
# 2896                               280      Киев       до 50 человек  ...
# 3043                               300     Днепр       до 50 человек  ...
# 3552                                 0      Киев       до 10 человек  ...
# 3566                                 0   Харьков      до 200 человек  ...
# 3598                               250  Черкассы       до 50 человек  ...
# 4300                                 0    Другой  свыше 1000 человек  ...
# 5012                               160      Киев       до 10 человек  ...
# 5438                               200      Киев  свыше 1000 человек  ...
# 5671                               100    Одесса       до 50 человек  ...
# 6153                               600     Львов  свыше 1000 человек  ...
# 6168                               300      Киев      до 200 человек  ...
# 6385                                 0      Киев       до 10 человек  ...
# 7333                                70      Киев       до 50 человек  ...
# 7539                               150   Харьков      до 200 человек  ...
# 7799                                 0      Киев       до 10 человек  ...
# 8090                               150      Киев      до 200 человек  ...
# 8169                                 0      Киев      до 200 человек  ...
# 8529                                 0      Киев     до 1000 человек  ...
#
#      Еще.студент Уровень.английского  \
# 50         False       выше среднего
# 351        False       выше среднего
# 1310       False       ниже среднего
# 1537       False       выше среднего
# 2295       False             средний
# 2310       False             средний
# 2345       False             средний
# 2856       False             средний
# 2896       False        элементарный
# 3043       False       ниже среднего
# 3552       False             средний
# 3566       False       ниже среднего
# 3598       False             средний
# 4300       False         продвинутый
# 5012       False        элементарный
# 5438       False             средний
# 5671       False             средний
# 6153       False         продвинутый
# 6168       False       выше среднего
# 6385       False             средний
# 7333       False             средний
# 7539       False             средний
# 7799       False       ниже среднего
# 8090       False             средний
# 8169       False       ниже среднего
# 8529       False       выше среднего
#
#                               Предметная.область      Дата.заполнения  \
# 50                                        Другое  12/06/2017 13:09:52
# 351       Телекоммуникации,Корпоративные системы  12/06/2017 13:53:53
# 1310      Телекоммуникации,Корпоративные системы  12/06/2017 18:37:07
# 1537                                      Другое  12/06/2017 21:13:44
# 2295                             Финансы и банки  13/06/2017 12:01:15
# 2310                       Корпоративные системы  13/06/2017 12:12:17
# 2345                     Gamedev,Финансы и банки  13/06/2017 12:14:36
# 2856                              Веб-разработка  13/06/2017 13:15:37
# 2896                             Финансы и банки  13/06/2017 13:24:34
# 3043                                      Другое  13/06/2017 14:14:24
# 3552                              Веб-разработка  13/06/2017 20:25:58
# 3566                                         NaN  13/06/2017 20:41:22
# 3598                    Веб-разработка,eCommerce  13/06/2017 21:23:41
# 4300                       Корпоративные системы  15/06/2017 10:29:30
# 5012  Desktop Applications,Корпоративные системы  19/06/2017 12:26:31
# 5438                       Корпоративные системы  20/06/2017 16:44:57
# 5671                                      Другое  20/06/2017 17:46:12
# 6153                                   eCommerce  21/06/2017 12:30:54
# 6168         Desktop Applications,Веб-разработка  21/06/2017 12:57:21
# 6385         Desktop Applications,Веб-разработка  22/06/2017 11:18:40
# 7333                              Веб-разработка  28/06/2017 23:53:45
# 7539                       Корпоративные системы  01/07/2017 11:51:04
# 7799                                      Другое  04/07/2017 15:58:08
# 8090                             Финансы и банки  06/07/2017 12:48:54
# 8169                                      Другое  06/07/2017 15:45:22
# 8529                             Финансы и банки  10/07/2017 10:53:28
#
#                                              User.Agent   exp current_job_exp  \
# 50    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   8.0             0.5
# 351   Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   4.0             1.0
# 1310  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   2.0             2.0
# 1537  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  10.0             0.5
# 2295  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....   3.0             3.0
# 2310  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  10.0             7.0
# 2345  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...   5.0             1.5
# 2856  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...   2.0             2.0
# 2896  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....  10.0            10.0
# 3043  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   2.0             0.5
# 3552  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...   0.5             0.5
# 3566  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   3.0             0.0
# 3598  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:53.0) G...   1.5             0.0
# 4300  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   8.0             2.0
# 5012  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  10.0             4.0
# 5438  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:5...   5.0             1.5
# 5671  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  10.0             2.0
# 6153  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   2.0             0.5
# 6168  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:54.0) ...   8.0             2.0
# 6385  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...  10.0             5.0
# 7333  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   6.0             6.0
# 7539  Mozilla/5.0 (Linux; Android 7.0; SM-G920F Buil...   7.0             3.0
# 7799  Mozilla/5.0 (Windows NT 6.1; rv:54.0) Gecko/20...   7.0             2.0
# 8090  Mozilla/5.0 (Linux; Android 7.1.1; GT-I9295 Bu...   0.5             0.0
# 8169  Mozilla/5.0 (Linux; Android 7.1.2; Nexus 4 Bui...  10.0             1.5
# 8529  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:54.0) ...   1.5             1.5
#
#      salary Валюта  cls
# 50     3500    NaN  NaN
# 351    2000    NaN  NaN
# 1310    510    NaN  NaN
# 1537   6000    NaN  NaN
# 2295   1200    NaN  NaN
# 2310   1300    NaN  NaN
# 2345   3000    NaN  NaN
# 2856    615    NaN  NaN
# 2896   1300    NaN  NaN
# 3043    600    NaN  NaN
# 3552    700    NaN  NaN
# 3566    900    NaN  NaN
# 3598    700    NaN  NaN
# 4300   2000    NaN  NaN
# 5012    920    NaN  NaN
# 5438   2090    NaN  NaN
# 5671   1200    NaN  NaN
# 6153   1400    NaN  NaN
# 6168   2000    NaN  NaN
# 6385    500    NaN  NaN
# 7333    570    NaN  NaN
# 7539   2150    NaN  NaN
# 7799   2200    NaN  NaN
# 8090    380    NaN  NaN
# 8169   2750    NaN  NaN
# 8529   2500    NaN  NaN
#
# [26 rows x 25 columns]
# Посада: Data Scientist / Data Analyst
#          N                      Должность Язык.программирования Специализация  \
# 28      29  Data Scientist / Data Analyst                   NaN           NaN
# 99     100  Data Scientist / Data Analyst                   NaN           NaN
# 294    295  Data Scientist / Data Analyst                   NaN           NaN
# 374    375  Data Scientist / Data Analyst                   NaN           NaN
# 416    417  Data Scientist / Data Analyst                   NaN           NaN
# ...    ...                            ...                   ...           ...
# 8408  8409  Data Scientist / Data Analyst                   NaN           NaN
# 8414  8415  Data Scientist / Data Analyst                   NaN           NaN
# 8487  8488  Data Scientist / Data Analyst                   NaN           NaN
# 8615  8616  Data Scientist / Data Analyst                   NaN           NaN
# 8693  8694  Data Scientist / Data Analyst                   NaN           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 28                0.25                         0.25               350
# 99      10 и более лет                            7              3900
# 294                  7                            2              2400
# 374   меньше 3 месяцев             меньше 3 месяцев               300
# 416                  3                            2               280
# ...                ...                          ...               ...
# 8408                 5                            1              1600
# 8414                 4                          1.5               850
# 8487                 1                            1               310
# 8615                 2                          1.5               400
# 8693               0.5                          0.5               270
#
#       Изменение.зарплаты.за.12.месяцев      Город  Размер.компании  ...  \
# 28                                   0       Киев    до 50 человек  ...
# 99                                   0    Харьков   до 200 человек  ...
# 294                                  0     Другой    до 10 человек  ...
# 374                                  0       Киев    до 10 человек  ...
# 416                                290  Запорожье    до 50 человек  ...
# ...                                ...        ...              ...  ...
# 8408                               200       Киев    до 10 человек  ...
# 8414                               450      Днепр  до 1000 человек  ...
# 8487                               100    Харьков  до 1000 человек  ...
# 8615                               100     Одесса    до 10 человек  ...
# 8693                                 0    Харьков    до 50 человек  ...
#
#      Еще.студент Уровень.английского            Предметная.область  \
# 28         False             средний                   Мультимедиа
# 99         False       выше среднего                Веб-разработка
# 294        False       выше среднего      Android,Телекоммуникации
# 374        False             средний               Финансы и банки
# 416        False             средний                Веб-разработка
# ...          ...                 ...                           ...
# 8408       False         продвинутый                     eCommerce
# 8414       False             средний                       Gamedev
# 8487        True             средний  Корпоративные системы,Другое
# 8615       False             средний      Веб-разработка,eCommerce
# 8693        True       выше среднего              eCommerce,Другое
#
#           Дата.заполнения                                         User.Agent  \
# 28    12/06/2017 13:08:00  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 99    12/06/2017 13:13:17  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 294   12/06/2017 13:44:51  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:42....
# 374   12/06/2017 13:58:44  Mozilla/5.0 (Linux; Android 4.2.1; Lenovo P780...
# 416   12/06/2017 14:06:35  Mozilla/5.0 (Linux; Android 5.1; K6000 Build/L...
# ...                   ...                                                ...
# 8408  08/07/2017 01:35:55  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8414  08/07/2017 09:28:16  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8487  09/07/2017 16:33:33  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8615  11/07/2017 14:09:30  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 8693  12/07/2017 14:14:27  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
#
#         exp current_job_exp salary Валюта  cls
# 28     0.25            0.25    350    NaN  NaN
# 99    10.00            7.00   3900    NaN  NaN
# 294    7.00            2.00   2400    NaN  NaN
# 374    0.00            0.00    300    NaN  NaN
# 416    3.00            2.00    280    NaN  NaN
# ...     ...             ...    ...    ...  ...
# 8408   5.00            1.00   1600    NaN  NaN
# 8414   4.00            1.50    850    NaN  NaN
# 8487   1.00            1.00    310    NaN  NaN
# 8615   2.00            1.50    400    NaN  NaN
# 8693   0.50            0.50    270    NaN  NaN
#
# [79 rows x 25 columns]
# Посада: Designer
#          N Должность Язык.программирования Специализация Общий.опыт.работы  \
# 89      90  Designer                   NaN           NaN                 2
# 203    204  Designer                   NaN           NaN                 5
# 208    209  Designer                   NaN           NaN                 4
# 261    262  Designer                   NaN           NaN                 5
# 471    472  Designer                   NaN           NaN                 1
# ...    ...       ...                   ...           ...               ...
# 8536  8537  Designer                   NaN           NaN    10 и более лет
# 8638  8639  Designer                   NaN           NaN                 8
# 8658  8659  Designer                   NaN           NaN                 1
# 8687  8688  Designer                   NaN           NaN                 2
# 8696  8697  Designer                   NaN           NaN    10 и более лет
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 89                            1.5               850
# 203                             1              1520
# 208                             3              2050
# 261              меньше 3 месяцев              1400
# 471                             2              2800
# ...                           ...               ...
# 8536                            3               650
# 8638                            1              2700
# 8658                          0.5               500
# 8687                          1.5               580
# 8696                            7              2000
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 89                                 300  Харьков       до 50 человек  ...
# 203                                  0     Киев  свыше 1000 человек  ...
# 208                               1350     Киев  свыше 1000 человек  ...
# 261                                400   Одесса      до 200 человек  ...
# 471                               1300  Харьков       до 10 человек  ...
# ...                                ...      ...                 ...  ...
# 8536                               650    Днепр       до 50 человек  ...
# 8638                               400     Киев       до 50 человек  ...
# 8658                                 0   Другой       до 10 человек  ...
# 8687                               180  Харьков  свыше 1000 человек  ...
# 8696                               200    Львов      до 200 человек  ...
#
#      Еще.студент Уровень.английского                    Предметная.область  \
# 89          True             средний                           Android,iOS
# 203        False             средний  Веб-разработка,Корпоративные системы
# 208        False             средний                                Другое
# 261        False       выше среднего                                Другое
# 471        False       выше среднего                      eCommerce,Другое
# ...          ...                 ...                                   ...
# 8536       False        элементарный                Android,Веб-разработка
# 8638       False       выше среднего                    iOS,Веб-разработка
# 8658       False       ниже среднего                           Мультимедиа
# 8687       False       ниже среднего                    iOS,Веб-разработка
# 8696       False         продвинутый                        Веб-разработка
#
#           Дата.заполнения                                         User.Agent  \
# 89    12/06/2017 13:12:26  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...
# 203   12/06/2017 13:29:20  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...
# 208   12/06/2017 13:29:52  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
# 261   12/06/2017 13:40:51  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
# 471   12/06/2017 14:18:08  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# ...                   ...                                                ...
# 8536  10/07/2017 11:45:22  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8638  11/07/2017 18:24:15  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 8658  11/07/2017 23:17:23  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8687  12/07/2017 12:12:39  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 8696  12/07/2017 14:47:26  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
#
#        exp current_job_exp salary Валюта  cls
# 89     2.0             1.5    850    NaN  NaN
# 203    5.0             1.0   1520    NaN  NaN
# 208    4.0             3.0   2050    NaN  NaN
# 261    5.0             0.0   1400    NaN  NaN
# 471    1.0             2.0   2800    NaN  NaN
# ...    ...             ...    ...    ...  ...
# 8536  10.0             3.0    650    NaN  NaN
# 8638   8.0             1.0   2700    NaN  NaN
# 8658   1.0             0.5    500    NaN  NaN
# 8687   2.0             1.5    580    NaN  NaN
# 8696  10.0             7.0   2000    NaN  NaN
#
# [223 rows x 25 columns]
# Посада: DevOps
#          N Должность Язык.программирования Специализация Общий.опыт.работы  \
# 108    109    DevOps                   NaN           NaN                 9
# 173    174    DevOps                   NaN           NaN               1.5
# 257    258    DevOps                   NaN           NaN               1.5
# 275    276    DevOps                   NaN           NaN                 5
# 326    327    DevOps                   NaN           NaN                 3
# ...    ...       ...                   ...           ...               ...
# 8346  8347    DevOps                   NaN           NaN    10 и более лет
# 8438  8439    DevOps                   NaN           NaN                 1
# 8498  8499    DevOps                   NaN           NaN    10 и более лет
# 8627  8628    DevOps                   NaN           NaN                 4
# 8679  8680    DevOps                   NaN           NaN                 5
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 108              меньше 3 месяцев              3500
# 173                          0.25               800
# 257                           1.5              1450
# 275                          0.25              2500
# 326                             3              2300
# ...                           ...               ...
# 8346               10 и более лет              2250
# 8438                            1              1000
# 8498                            2              5500
# 8627                            4              1500
# 8679                            9              1100
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 108                                500     Киев  свыше 1000 человек  ...
# 173                                350    Днепр     до 1000 человек  ...
# 257                                500     Киев       до 10 человек  ...
# 275                                700     Киев  свыше 1000 человек  ...
# 326                                  0    Днепр      до 200 человек  ...
# ...                                ...      ...                 ...  ...
# 8346                                 0    Днепр      до 200 человек  ...
# 8438                                 0     Киев     до 1000 человек  ...
# 8498                               500   Одесса       до 50 человек  ...
# 8627                               250  Житомир  свыше 1000 человек  ...
# 8679                               360     Киев      до 200 человек  ...
#
#      Еще.студент Уровень.английского                    Предметная.область  \
# 108        False             средний  Desktop Applications,Финансы и банки
# 173        False             средний              Веб-разработка,eCommerce
# 257        False       выше среднего                             eCommerce
# 275        False             средний                 Корпоративные системы
# 326        False             средний                        Веб-разработка
# ...          ...                 ...                                   ...
# 8346       False             средний                                Другое
# 8438       False        элементарный                 Веб-разработка,Другое
# 8498       False             средний               Веб-разработка,Embedded
# 8627       False             средний                  Desktop Applications
# 8679       False             средний                 Корпоративные системы
#
#           Дата.заполнения                                         User.Agent  \
# 108   12/06/2017 13:13:55  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 173   12/06/2017 13:23:00  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 257   12/06/2017 13:40:00  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 275   12/06/2017 13:42:37  Mozilla/5.0 (Linux; Android 7.1.2; Pixel Build...
# 326   12/06/2017 13:50:30  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# ...                   ...                                                ...
# 8346  07/07/2017 15:15:55  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 8438  08/07/2017 16:25:53  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8498  09/07/2017 20:07:26  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# 8627  11/07/2017 16:24:44  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:5...
# 8679  12/07/2017 11:09:19  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#        exp current_job_exp salary Валюта  cls
# 108    9.0            0.00   3500    NaN  ADM
# 173    1.5            0.25    800    NaN  ADM
# 257    1.5            1.50   1450    NaN  ADM
# 275    5.0            0.25   2500    NaN  ADM
# 326    3.0            3.00   2300    NaN  ADM
# ...    ...             ...    ...    ...  ...
# 8346  10.0           10.00   2250    NaN  ADM
# 8438   1.0            1.00   1000    NaN  ADM
# 8498  10.0            2.00   5500    NaN  ADM
# 8627   4.0            4.00   1500    NaN  ADM
# 8679   5.0            9.00   1100    NaN  ADM
#
# [170 rows x 25 columns]
# Посада: Director of Engineering / Program Director
#          N                                   Должность Язык.программирования  \
# 152    153  Director of Engineering / Program Director                   NaN
# 594    595  Director of Engineering / Program Director                   NaN
# 677    678  Director of Engineering / Program Director                   NaN
# 791    792  Director of Engineering / Program Director                   NaN
# 1181  1182  Director of Engineering / Program Director                   NaN
# 1333  1334  Director of Engineering / Program Director                   NaN
# 1394  1395  Director of Engineering / Program Director                   NaN
# 1477  1478  Director of Engineering / Program Director                   NaN
# 2107  2108  Director of Engineering / Program Director                   NaN
# 2273  2274  Director of Engineering / Program Director                   NaN
# 2590  2591  Director of Engineering / Program Director                   NaN
# 2961  2962  Director of Engineering / Program Director                   NaN
# 3468  3469  Director of Engineering / Program Director                   NaN
# 3497  3498  Director of Engineering / Program Director                   NaN
# 3627  3628  Director of Engineering / Program Director                   NaN
# 3728  3729  Director of Engineering / Program Director                   NaN
# 3775  3776  Director of Engineering / Program Director                   NaN
# 3945  3946  Director of Engineering / Program Director                   NaN
# 3946  3947  Director of Engineering / Program Director                   NaN
# 4152  4153  Director of Engineering / Program Director                   NaN
# 4365  4366  Director of Engineering / Program Director                   NaN
# 4691  4692  Director of Engineering / Program Director                   NaN
# 4998  4999  Director of Engineering / Program Director                   NaN
# 5013  5014  Director of Engineering / Program Director                   NaN
# 5101  5102  Director of Engineering / Program Director                   NaN
# 5342  5343  Director of Engineering / Program Director                   NaN
# 5369  5370  Director of Engineering / Program Director                   NaN
# 5511  5512  Director of Engineering / Program Director                   NaN
# 5563  5564  Director of Engineering / Program Director                   NaN
# 5727  5728  Director of Engineering / Program Director                   NaN
# 5813  5814  Director of Engineering / Program Director                   NaN
# 5870  5871  Director of Engineering / Program Director                   NaN
# 6438  6439  Director of Engineering / Program Director                   NaN
# 6741  6742  Director of Engineering / Program Director                   NaN
# 6771  6772  Director of Engineering / Program Director                   NaN
# 6821  6822  Director of Engineering / Program Director                   NaN
# 6857  6858  Director of Engineering / Program Director                   NaN
# 6879  6880  Director of Engineering / Program Director                   NaN
# 6930  6931  Director of Engineering / Program Director                   NaN
# 7009  7010  Director of Engineering / Program Director                   NaN
# 7089  7090  Director of Engineering / Program Director                   NaN
# 7753  7754  Director of Engineering / Program Director                   NaN
# 8459  8460  Director of Engineering / Program Director                   NaN
# 8659  8660  Director of Engineering / Program Director                   NaN
#
#      Специализация Общий.опыт.работы Опыт.работы.на.текущем.месте  \
# 152            NaN    10 и более лет                            7
# 594            NaN                 9                            6
# 677            NaN    10 и более лет                          0.5
# 791            NaN                 7                            2
# 1181           NaN    10 и более лет               10 и более лет
# 1333           NaN    10 и более лет               10 и более лет
# 1394           NaN    10 и более лет                            2
# 1477           NaN    10 и более лет                            4
# 2107           NaN                 8                            4
# 2273           NaN    10 и более лет                            9
# 2590           NaN    10 и более лет               10 и более лет
# 2961           NaN                 9                            2
# 3468           NaN    10 и более лет               10 и более лет
# 3497           NaN                 8                            1
# 3627           NaN                 5                            9
# 3728           NaN    10 и более лет                          0.5
# 3775           NaN                 5                            1
# 3945           NaN                 9                            6
# 3946           NaN    10 и более лет                            1
# 4152           NaN    10 и более лет                          0.5
# 4365           NaN    10 и более лет                            3
# 4691           NaN    10 и более лет                            2
# 4998           NaN                 3                            5
# 5013           NaN    10 и более лет               10 и более лет
# 5101           NaN                 6                            1
# 5342           NaN    10 и более лет                            2
# 5369           NaN    10 и более лет                          1.5
# 5511           NaN    10 и более лет                            4
# 5563           NaN    10 и более лет                            6
# 5727           NaN                 5                            3
# 5813           NaN    10 и более лет                          0.5
# 5870           NaN    10 и более лет                            7
# 6438           NaN                 9                            8
# 6741           NaN                 5                            3
# 6771           NaN    10 и более лет               10 и более лет
# 6821           NaN                 4                            3
# 6857           NaN                 9                            3
# 6879           NaN    10 и более лет                          1.5
# 6930           NaN    10 и более лет                            7
# 7009           NaN    10 и более лет                            6
# 7089           NaN    10 и более лет                          0.5
# 7753           NaN    10 и более лет             меньше 3 месяцев
# 8459           NaN                 4                            4
# 8659           NaN    10 и более лет                            2
#
#       Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев         Город  \
# 152               8500                               500          Киев
# 594              34000                                 0          Киев
# 677               2900                                 0         Львов
# 791               4800                               200          Киев
# 1181              5500                              -200       Харьков
# 1333              4000                              1000         Львов
# 1394              6000                              1500          Киев
# 1477              5200                               500         Днепр
# 2107              4000                               500         Львов
# 2273              3920                               510          Киев
# 2590              3800                                 0       Винница
# 2961              4600                                 0       Харьков
# 3468              2000                               200          Киев
# 3497              4500                                 0          Киев
# 3627              1750                                 0       Харьков
# 3728              3000                                 0        Одесса
# 3775              7500                                 0          Киев
# 3945              7100                               542          Киев
# 3946              5000                                 0          Киев
# 4152              1900                               830          Киев
# 4365              4750                              1000       Харьков
# 4691              4600                                 0       Харьков
# 4998              3700                                 0          Киев
# 5013              5200                               151          Киев
# 5101              4000                               800         Львов
# 5342              5000                                 0          Киев
# 5369              7000                              1500          Киев
# 5511              5000                                 0          Киев
# 5563              5500                                 0          Киев
# 5727              5500                               500          Киев
# 5813              4200                               200          Киев
# 5870              2850                               500  Кропивницкий
# 6438              3200                               400       Харьков
# 6741              1500                                 0          Киев
# 6771              5200                               350         Львов
# 6821              2300                              1000          Киев
# 6857              5000                                 0       Харьков
# 6879              5500                                 0          Киев
# 6930              5000                                 0       Харьков
# 7009              4500                               150          Киев
# 7089              4000                                 0          Киев
# 7753              1700                                 0          Киев
# 8459              3000                              1500          Киев
# 8659              4750                                 0          Киев
#
#          Размер.компании  ... Еще.студент Уровень.английского  \
# 152        до 50 человек  ...       False         продвинутый
# 594        до 50 человек  ...       False         продвинутый
# 677        до 10 человек  ...       False         продвинутый
# 791   свыше 1000 человек  ...       False         продвинутый
# 1181     до 1000 человек  ...       False             средний
# 1333       до 50 человек  ...       False       выше среднего
# 1394      до 200 человек  ...       False             средний
# 1477      до 200 человек  ...       False         продвинутый
# 2107     до 1000 человек  ...       False       выше среднего
# 2273       до 50 человек  ...       False         продвинутый
# 2590       до 10 человек  ...       False       выше среднего
# 2961     до 1000 человек  ...       False         продвинутый
# 3468       до 10 человек  ...       False             средний
# 3497       до 50 человек  ...       False         продвинутый
# 3627       до 10 человек  ...       False       ниже среднего
# 3728       до 10 человек  ...       False       выше среднего
# 3775      до 200 человек  ...       False         продвинутый
# 3945     до 1000 человек  ...       False         продвинутый
# 3946       до 50 человек  ...       False       выше среднего
# 4152       до 10 человек  ...       False             средний
# 4365       до 10 человек  ...       False       выше среднего
# 4691       до 50 человек  ...       False         продвинутый
# 4998      до 200 человек  ...       False       выше среднего
# 5013      до 200 человек  ...       False       выше среднего
# 5101       до 50 человек  ...       False             средний
# 5342       до 50 человек  ...       False             средний
# 5369  свыше 1000 человек  ...       False         продвинутый
# 5511       до 50 человек  ...       False       выше среднего
# 5563       до 50 человек  ...       False       выше среднего
# 5727       до 10 человек  ...       False       выше среднего
# 5813       до 50 человек  ...       False       выше среднего
# 5870      до 200 человек  ...       False       выше среднего
# 6438       до 50 человек  ...       False         продвинутый
# 6741       до 50 человек  ...       False       выше среднего
# 6771  свыше 1000 человек  ...       False       выше среднего
# 6821  свыше 1000 человек  ...       False             средний
# 6857       до 50 человек  ...       False       выше среднего
# 6879      до 200 человек  ...       False         продвинутый
# 6930       до 50 человек  ...       False         продвинутый
# 7009      до 200 человек  ...       False         продвинутый
# 7089       до 50 человек  ...       False       выше среднего
# 7753       до 10 человек  ...       False         продвинутый
# 8459     до 1000 человек  ...       False       выше среднего
# 8659      до 200 человек  ...       False         продвинутый
#
#                               Предметная.область      Дата.заполнения  \
# 152                    Embedded,Телекоммуникации  12/06/2017 13:20:11
# 594                           iOS,Веб-разработка  12/06/2017 14:45:22
# 677                       Финансы и банки,Другое  12/06/2017 14:59:36
# 791       Телекоммуникации,Корпоративные системы  12/06/2017 15:28:37
# 1181                                      Другое  12/06/2017 17:40:39
# 1333        Веб-разработка,Корпоративные системы  12/06/2017 18:53:27
# 1394                     Android,Финансы и банки  12/06/2017 19:32:17
# 1477                                      Другое  12/06/2017 20:37:39
# 2107                                     Gamedev  13/06/2017 10:08:21
# 2273  Desktop Applications,Корпоративные системы  13/06/2017 11:45:19
# 2590                                      Другое  13/06/2017 12:32:15
# 2961             Веб-разработка,Телекоммуникации  13/06/2017 13:46:54
# 3468                Корпоративные системы,Другое  13/06/2017 18:28:57
# 3497                            Телекоммуникации  13/06/2017 18:59:37
# 3627                                     Gamedev  13/06/2017 22:00:52
# 3728                              Веб-разработка  14/06/2017 00:38:51
# 3775                    iOS,Desktop Applications  14/06/2017 08:51:16
# 3945                      Веб-разработка,Gamedev  14/06/2017 12:36:55
# 3946        Веб-разработка,Корпоративные системы  14/06/2017 12:37:48
# 4152                                      Другое  14/06/2017 19:31:59
# 4365        Веб-разработка,Корпоративные системы  15/06/2017 12:39:51
# 4691                  Системное программирование  16/06/2017 16:10:18
# 4998                                     Gamedev  19/06/2017 10:20:21
# 5013                       Веб-разработка,Другое  19/06/2017 13:24:55
# 5101                      Android,Веб-разработка  20/06/2017 10:40:37
# 5342                    Веб-разработка,eCommerce  20/06/2017 16:33:32
# 5369                Телекоммуникации,Мультимедиа  20/06/2017 16:36:08
# 5511                       Веб-разработка,Другое  20/06/2017 16:57:36
# 5563                    Веб-разработка,eCommerce  20/06/2017 17:10:03
# 5727                       Корпоративные системы  20/06/2017 18:22:13
# 5813                              Веб-разработка  20/06/2017 20:00:31
# 5870        Веб-разработка,Корпоративные системы  20/06/2017 21:24:15
# 6438                    Веб-разработка,eCommerce  22/06/2017 15:43:05
# 6741                                      Другое  25/06/2017 21:52:02
# 6771        Веб-разработка,Корпоративные системы  26/06/2017 11:10:28
# 6821                       Корпоративные системы  26/06/2017 11:22:04
# 6857                              Веб-разработка  26/06/2017 11:37:48
# 6879                       Корпоративные системы  26/06/2017 11:49:36
# 6930                               iOS,eCommerce  26/06/2017 12:50:09
# ...
# 111                                150    Днепр      до 200 человек  ...
# 219                                100     Киев      до 200 человек  ...
# ...                                ...      ...                 ...  ...
# 8637                               300     Киев  свыше 1000 человек  ...
# 8645                               200  Харьков      до 200 человек  ...
# 8652                                 0    Львов  свыше 1000 человек  ...
# 8660                               350     Киев  свыше 1000 человек  ...
# 8682                                 0  Харьков     до 1000 человек  ...
#
#      Еще.студент Уровень.английского                    Предметная.область  \
# 44         False       выше среднего                       Финансы и банки
# 52         False         продвинутый                           Мультимедиа
# 54         False       выше среднего              Веб-разработка,eCommerce
# 111        False       выше среднего                        Веб-разработка
# 219        False       ниже среднего                       Финансы и банки
# ...          ...                 ...                                   ...
# 8637       False       выше среднего  Веб-разработка,Корпоративные системы
# 8645       False             средний                        Веб-разработка
# 8652       False       выше среднего              Веб-разработка,eCommerce
# 8660       False             средний                        Веб-разработка
# 8682       False       ниже среднего                                   iOS
#
#           Дата.заполнения                                         User.Agent  \
# 44    12/06/2017 13:09:29  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
# 52    12/06/2017 13:09:57  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 54    12/06/2017 13:10:01  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
# 111   12/06/2017 13:14:33  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 219   12/06/2017 13:32:39  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# ...                   ...                                                ...
# 8637  11/07/2017 18:06:13  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 8645  11/07/2017 21:12:58  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8652  11/07/2017 22:56:10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8660  11/07/2017 23:38:01  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8682  12/07/2017 11:38:02  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
#
#        exp current_job_exp salary Валюта   cls
# 44     6.0             4.0   3400    NaN  SDEV
# 52    10.0             4.0   4500    NaN  SDEV
# 54     6.0             3.0   3000    NaN  SDEV
# 111   10.0            10.0   4150    NaN  SDEV
# 219   10.0             4.0   3000    NaN  SDEV
# ...    ...             ...    ...    ...   ...
# 8637   7.0             7.0   3325    NaN  SDEV
# 8645  10.0             6.0   2950    NaN  SDEV
# 8652  10.0             5.0   4275    NaN  SDEV
# 8660   6.0             1.5   4350    NaN  SDEV
# 8682  10.0             3.0   3200    NaN  SDEV
#
# [250 rows x 25 columns]
# Посада: Technical writer
#          N         Должность Язык.программирования Специализация  \
# 187    188  Technical writer                   NaN           NaN
# 384    385  Technical writer                   NaN           NaN
# 857    858  Technical writer                   NaN           NaN
# 1096  1097  Technical writer                   NaN           NaN
# 2445  2446  Technical writer                   NaN           NaN
# 2783  2784  Technical writer                   NaN           NaN
# 3378  3379  Technical writer                   NaN           NaN
# 3983  3984  Technical writer                   NaN           NaN
# 4330  4331  Technical writer                   NaN           NaN
# 4646  4647  Technical writer                   NaN           NaN
# 5061  5062  Technical writer                   NaN           NaN
# 5633  5634  Technical writer                   NaN           NaN
# 5823  5824  Technical writer                   NaN           NaN
# 5890  5891  Technical writer                   NaN           NaN
# 6162  6163  Technical writer                   NaN           NaN
# 6535  6536  Technical writer                   NaN           NaN
# 6547  6548  Technical writer                   NaN           NaN
# 6694  6695  Technical writer                   NaN           NaN
# 6986  6987  Technical writer                   NaN           NaN
# 7311  7312  Technical writer                   NaN           NaN
# 7504  7505  Technical writer                   NaN           NaN
# 7562  7563  Technical writer                   NaN           NaN
# 7869  7870  Technical writer                   NaN           NaN
# 7883  7884  Technical writer                   NaN           NaN
# 8052  8053  Technical writer                   NaN           NaN
# 8279  8280  Technical writer                   NaN           NaN
# 8338  8339  Technical writer                   NaN           NaN
# 8513  8514  Technical writer                   NaN           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 187                  5                            3              3000
# 384                  3                            3              1000
# 857                  3                          1.5              1100
# 1096                 6                            1              2700
# 2445                 2                            2              1700
# 2783                 4                          0.5               600
# 3378                 4                            4              1500
# 3983                 1                            1               800
# 4330                 7                         0.25               600
# 4646                 4                            4              1226
# 5061                 2                          0.5               350
# 5633                 3                            1              1500
# 5823  меньше 3 месяцев             меньше 3 месяцев               600
# 5890  меньше 3 месяцев             меньше 3 месяцев               300
# 6162                 1             меньше 3 месяцев               800
# 6535                 7                            4              2000
# 6547                 1                          0.5               440
# 6694                 2                            1              1805
# 6986                 2             меньше 3 месяцев               400
# 7311               1.5                          1.5               600
# 7504               1.5                          1.5               790
# 7562                 5             меньше 3 месяцев               200
# 7869                 3                            2               800
# 7883              0.25                          1.5               400
# 8052    10 и более лет                            2               600
# 8279                 6                            5               920
# 8338    10 и более лет                            5              2350
# 8513                 5                            2              2500
#
#       Изменение.зарплаты.за.12.месяцев      Город     Размер.компании  ...  \
# 187                                500       Киев     до 1000 человек  ...
# 384                                400      Львов  свыше 1000 человек  ...
# 857                                100       Киев      до 200 человек  ...
# 1096                                 0       Киев      до 200 человек  ...
# 2445                               300       Киев      до 200 человек  ...
# 2783                               400   Удаленно      до 200 человек  ...
# 3378                               500      Львов  свыше 1000 человек  ...
# 3983                               150       Киев       до 50 человек  ...
# 4330                               100       Киев       до 10 человек  ...
# 4646                                14       Киев      до 200 человек  ...
# 5061                                50       Киев       до 50 человек  ...
# 5633                               200       Киев      до 200 человек  ...
# 5823                               100     Одесса       до 50 человек  ...
# 5890                                 0       Киев  свыше 1000 человек  ...
# 6162                               500       Киев       до 50 человек  ...
# 6535                               300    Харьков      до 200 человек  ...
# 6547                               160       Киев       до 50 человек  ...
# 6694                                95       Киев  свыше 1000 человек  ...
# 6986                                 0      Днепр       до 50 человек  ...
# 7311                                 0  Запорожье       до 10 человек  ...
# 7504                               190       Киев     до 1000 человек  ...
# 7562                                15     Другой       до 50 человек  ...
# 7869                               250      Львов       до 50 человек  ...
# 7883                               100      Днепр     до 1000 человек  ...
# 8052                               100       Киев      до 200 человек  ...
# 8279                               150       Киев     до 1000 человек  ...
# 8338                               300       Киев      до 200 человек  ...
# 8513                               500       Киев       до 50 человек  ...
#
#      Еще.студент Уровень.английского  \
# 187        False         продвинутый
# 384        False         продвинутый
# 857        False       выше среднего
# 1096       False         продвинутый
# 2445       False         продвинутый
# 2783       False         продвинутый
# 3378       False         продвинутый
# 3983       False         продвинутый
# 4330       False             средний
# 4646       False       выше среднего
# 5061       False         продвинутый
# 5633       False         продвинутый
# 5823       False         продвинутый
# 5890       False         продвинутый
# 6162       False         продвинутый
# 6535       False         продвинутый
# 6547        True         продвинутый
# 6694       False         продвинутый
# 6986       False       ниже среднего
# 7311       False         продвинутый
# 7504       False       ниже среднего
# 7562       False             средний
# 7869       False         продвинутый
# 7883       False       выше среднего
# 8052       False             средний
# 8279       False             средний
# 8338       False         продвинутый
# 8513       False         продвинутый
#
#                               Предметная.область      Дата.заполнения  \
# 187                                       Другое  12/06/2017 13:25:23
# 384   Desktop Applications,Корпоративные системы  12/06/2017 14:00:45
# 857                  Desktop Applications,Другое  12/06/2017 15:45:06
# 1096                    Веб-разработка,eCommerce  12/06/2017 17:10:42
# 2445                      Веб-разработка,Gamedev  13/06/2017 12:19:41
# 2783                                      Другое  13/06/2017 13:01:05
# 3378            Телекоммуникации,Финансы и банки  13/06/2017 17:01:18
# 3983                             Финансы и банки  14/06/2017 13:52:48
# 4330                                      Другое  15/06/2017 11:26:08
# 4646                    Веб-разработка,eCommerce  16/06/2017 13:55:15
# 5061                            eCommerce,Другое  19/06/2017 21:53:50
# 5633                                      Другое  20/06/2017 17:29:48
# 5823                              Веб-разработка  20/06/2017 20:13:44
# 5890                                     Gamedev  20/06/2017 21:48:37
# 6162                                 Android,iOS  21/06/2017 12:49:23
# 6535                                      Другое  23/06/2017 11:38:28
# 6547                                      Другое  23/06/2017 12:20:54
# 6694                       Корпоративные системы  25/06/2017 08:25:31
# 6986                              Веб-разработка  26/06/2017 15:07:18
# 7311      Телекоммуникации,Корпоративные системы  28/06/2017 20:50:13
# 7504             eCommerce,Корпоративные системы  30/06/2017 20:14:02
# 7562                    Веб-разработка,eCommerce  01/07/2017 23:21:08
# 7869                          Мультимедиа,Другое  05/07/2017 11:05:31
# 7883                                     Gamedev  05/07/2017 11:59:19
# 8052                    Веб-разработка,eCommerce  06/07/2017 12:06:28
# 8279                       Корпоративные системы  07/07/2017 00:22:44
# 8338         Desktop Applications,Веб-разработка  07/07/2017 14:16:23
# 8513                  Веб-разработка,Мультимедиа  09/07/2017 23:28:04
#
#                                              User.Agent    exp  \
# 187   Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.00
# 384   Mozilla/5.0 (Linux; Android 6.0.1; LG-K220 Bui...   3.00
# 857   Mozilla/5.0 (Windows NT 10.0; WOW64; rv:53.0) ...   3.00
# 1096  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   6.00
# 2445  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   2.00
# 2783  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.00
# 3378  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   4.00
# 3983  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:53.0) G...   1.00
# 4330  Mozilla/5.0 (Windows NT 6.3; rv:54.0) Gecko/20...   7.00
# 4646  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   4.00
# 5061  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   2.00
# 5633  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   3.00
# 5823  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.00
# 5890  Mozilla/5.0 (Linux; Android 4.4.4; HTC Desire ...   0.00
# 6162  Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537....   1.00
# 6535  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...   7.00
# 6547  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.00
# 6694  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   2.00
# 6986  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   2.00
# 7311  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...   1.50
# 7504  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.50
# 7562  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   5.00
# 7869  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   3.00
# 7883  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:54.0) G...   0.25
# 8052  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:54.0) G...  10.00
# 8279  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   6.00
# 8338  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  10.00
# 8513  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...   5.00
#
#      current_job_exp salary Валюта  cls
# 187             3.00   3000    NaN  NaN
# 384             3.00   1000    NaN  NaN
# 857             1.50   1100    NaN  NaN
# 1096            1.00   2700    NaN  NaN
# 2445            2.00   1700    NaN  NaN
# 2783            0.50    600    NaN  NaN
# 3378            4.00   1500    NaN  NaN
# 3983            1.00    800    NaN  NaN
# 4330            0.25    600    NaN  NaN
# 4646            4.00   1226    NaN  NaN
# 5061            0.50    350    NaN  NaN
# 5633            1.00   1500    NaN  NaN
# 5823            0.00    600    NaN  NaN
# 5890            0.00    300    NaN  NaN
# 6162            0.00    800    NaN  NaN
# 6535            4.00   2000    NaN  NaN
# 6547            0.50    440    NaN  NaN
# 6694            1.00   1805    NaN  NaN
# 6986            0.00    400    NaN  NaN
# 7311            1.50    600    NaN  NaN
# 7504            1.50    790    NaN  NaN
# 7562            0.00    200    NaN  NaN
# 7869            2.00    800    NaN  NaN
# 7883            1.50    400    NaN  NaN
# 8052            2.00    600    NaN  NaN
# 8279            5.00    920    NaN  NaN
# 8338            5.00   2350    NaN  NaN
# 8513            2.00   2500    NaN  NaN
#
# [28 rows x 25 columns]

# %%
#Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", 
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Групуємо дані за стовпцем "Должность" і виконуємо агрегацію для стовпця "Зарплата.в.месяц"
aggregated_data = df.groupby("Должность")["Зарплата.в.месяц"].agg([min, max])

# Виводимо результат
print(aggregated_data)
# Out:
#                                              min    max
# Должность
# Business analyst                             200   5000
# DBA                                          380   6000
# Data Scientist / Data Analyst                150   8000
# Designer                                     100   4000
# DevOps                                       194  10000
# Director of Engineering / Program Director  1500  34000
# ERP / CRM                                    100   6000
# Game designer                                150   6800
# HR                                           100   7000
# HTML coder                                   154   3000
# Junior QA engineer                            96   2000
# Junior Software Engineer                      75   2600
# Marketing                                    100   4000
# Product Manager                              250   5000
# Project manager                              190   8000
# QA Tech Lead                                 430   6000
# QA engineer                                  150   2900
# Research Engineer                            114   4000
# Sales manager                                120   2300
# Scrum Master                                 370   4500
# Security Specialist                          300   4000
# Senior Project Manager / Program Manager     200   9100
# Senior QA engineer                           400   6000
# Senior Software Engineer                     350   9200
# Software Engineer                            100   7000
# Support                                      138   3650
# Sysadmin                                      90   3000
# System Architect                             400  10000
# Talent Researcher                            100   1700
# Team lead                                    300   7000
# Technical Lead                               500  18000
# Technical writer                             200   3000

# %%
#Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Функція для обчислення середньої зарплати
def fill_avg_salary(row):
    return row["Зарплата.в.месяц"]

# Застосовуємо функцію за допомогою методу apply і створюємо новий стовпець "avg"
df["avg"] = df.apply(fill_avg_salary, axis=1)
df
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                  0.5                          0.5               400
# 1     меньше 3 месяцев             меньше 3 месяцев               430
# 2                    4                            1              2500
# 3                    5                            4              2000
# 4       10 и более лет                          0.5              4500
# ...                ...                          ...               ...
# 8699                 1             меньше 3 месяцев               700
# 8700               0.5                          0.5               400
# 8701                 1                          0.5               800
# 8702                 6                            4              2600
# 8703                 7                            2              5000
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                    0  Харьков       до 10 человек  ...
# 1                                  130  Харьков  свыше 1000 человек  ...
# 2                                  800     Киев     до 1000 человек  ...
# 3                                  400   Одесса      до 200 человек  ...
# 4                                  500   Другой       до 10 человек  ...
# ...                                ...      ...                 ...  ...
# 8699                               700   Одесса       до 50 человек  ...
# 8700                               120     Киев       до 50 человек  ...
# 8701                               500    Львов       до 10 человек  ...
# 8702                                 0    Днепр  свыше 1000 человек  ...
# 8703                               800   Одесса     до 1000 человек  ...
#
#      Уровень.английского                    Предметная.область  \
# 0          ниже среднего                         iOS,eCommerce
# 1          выше среднего                        Веб-разработка
# 2                средний  Веб-разработка,Корпоративные системы
# 3          ниже среднего   Desktop Applications,Веб-разработка
# 4                средний   Desktop Applications,Веб-разработка
# ...                  ...                                   ...
# 8699             средний          Android,Desktop Applications
# 8700       ниже среднего                             eCommerce
# 8701       выше среднего  Веб-разработка,Корпоративные системы
# 8702         продвинутый                       Финансы и банки
# 8703       выше среднего                        Веб-разработка
#
#           Дата.заполнения                                         User.Agent  \
# 0     12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1     12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2     12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3     12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4     12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# ...                   ...                                                ...
# 8699  12/07/2017 15:45:24  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8700  12/07/2017 17:00:06  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8701  12/07/2017 17:32:26  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8702  12/07/2017 18:14:59  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 8703  12/07/2017 21:28:57  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
#
#        exp  current_job_exp salary Валюта  cls   avg
# 0      0.5              0.5    400    NaN   QA   400
# 1      0.0              0.0    430    NaN   QA   430
# 2      4.0              1.0   2500    NaN  DEV  2500
# 3      5.0              4.0   2000    NaN  DEV  2000
# 4     10.0              0.5   4500    NaN  DEV  4500
# ...    ...              ...    ...    ...  ...   ...
# 8699   1.0              0.0    700    NaN   QA   700
# 8700   0.5              0.5    400    NaN  NaN   400
# 8701   1.0              0.5    800    NaN  DEV   800
# 8702   6.0              4.0   2600    NaN   PM  2600
# 8703   7.0              2.0   5000    NaN  DEV  5000
#
# [8704 rows x 26 columns]

# %%
# описова статистику за допомогою методу describe для нового стовпчика.
statistics = df["avg"].describe()
print(statistics)
# Out:
# count     8704.000000
# mean      1666.704159
# std       1338.280986
# min         75.000000
# 25%        600.000000
# 50%       1300.000000
# 75%       2400.000000
# max      34000.000000
# Name: avg, dtype: float64

# %%
output_file_path = "output_data.csv"
df.to_csv(output_file_path, index=False)  # Параметр index=False для відключення збереження індексів

print(f"Таблицю збережено у файл {output_file_path}")
# Out:
# Таблицю збережено у файл output_data.csv

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (3.6.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\evgen\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Встановлюємо директиву для побудови графіків всередині Jupyter Notebook
# %matplotlib inline

# Функція для обчислення середньої зарплати
def fill_avg_salary(row):
    return row["Зарплата.в.месяц"]


# Завантажуємо дані з CSV файлу
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Створюємо новий стовпець "avg" за допомогою функції fill_avg_salary
df["avg"] = df.apply(fill_avg_salary, axis=1)

# Виводимо перші 5 рядків для перевірки
print(df.head())

# Побудова графіку
plt.figure(figsize=(10, 6))
plt.hist(df["avg"], bins=20, color='skyblue')
plt.title('Розподіл середньої зарплати на місяць')
plt.xlabel('Середня зарплата (грн)')
plt.ylabel('Кількість працівників')
plt.grid(True)
plt.tight_layout()

average_salary = df["avg"].mean()
print("Средняя зарплата: {:.2f} грн".format(average_salary))

# Відображення графіку
plt.show()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
# 3                               400   Одесса      до 200 человек  ...
# 4                               500   Другой       до 10 человек  ...
#
#   Уровень.английского                    Предметная.область  \
# 0       ниже среднего                         iOS,eCommerce
# 1       выше среднего                        Веб-разработка
# 2             средний  Веб-разработка,Корпоративные системы
# 3       ниже среднего   Desktop Applications,Веб-разработка
# 4             средний   Desktop Applications,Веб-разработка
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3  12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4  12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
#
#     exp  current_job_exp salary Валюта  cls   avg
# 0   0.5              0.5    400    NaN   QA   400
# 1   0.0              0.0    430    NaN   QA   430
# 2   4.0              1.0   2500    NaN  DEV  2500
# 3   5.0              4.0   2000    NaN  DEV  2000
# 4  10.0              0.5   4500    NaN  DEV  4500
#
# [5 rows x 26 columns]
# Средняя зарплата: 1666.70 грн

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Встановлюємо директиву для побудови графіків всередині Jupyter Notebook
# %matplotlib inline

# Завантажуємо дані з CSV файлу
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)
print (df)
# Побудова ящика для розподілу зарплати за кожною посадою
plt.figure(figsize=(12, 6))
sns.boxplot(x='Должность', y='Зарплата.в.месяц', data=df, palette='Set3')
plt.title('Розподіл зарплати за посадами')
plt.xlabel('Посада')
plt.ylabel('Зарплата (грн)')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()

# Відображення графіку
plt.show()
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                  0.5                          0.5               400
# 1     меньше 3 месяцев             меньше 3 месяцев               430
# 2                    4                            1              2500
# 3                    5                            4              2000
# 4       10 и более лет                          0.5              4500
# ...                ...                          ...               ...
# 8699                 1             меньше 3 месяцев               700
# 8700               0.5                          0.5               400
# 8701                 1                          0.5               800
# 8702                 6                            4              2600
# 8703                 7                            2              5000
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                    0  Харьков       до 10 человек  ...
# 1                                  130  Харьков  свыше 1000 человек  ...
# 2                                  800     Киев     до 1000 человек  ...
# 3                                  400   Одесса      до 200 человек  ...
# 4                                  500   Другой       до 10 человек  ...
# ...                                ...      ...                 ...  ...
# 8699                               700   Одесса       до 50 человек  ...
# 8700                               120     Киев       до 50 человек  ...
# 8701                               500    Львов       до 10 человек  ...
# 8702                                 0    Днепр  свыше 1000 человек  ...
# 8703                               800   Одесса     до 1000 человек  ...
#
#      Еще.студент Уровень.английского                    Предметная.область  \
# 0           True       ниже среднего                         iOS,eCommerce
# 1           True       выше среднего                        Веб-разработка
# 2          False             средний  Веб-разработка,Корпоративные системы
# 3          False       ниже среднего   Desktop Applications,Веб-разработка
# 4          False             средний   Desktop Applications,Веб-разработка
# ...          ...                 ...                                   ...
# 8699       False             средний          Android,Desktop Applications
# 8700       False       ниже среднего                             eCommerce
# 8701       False       выше среднего  Веб-разработка,Корпоративные системы
# 8702       False         продвинутый                       Финансы и банки
# 8703       False       выше среднего                        Веб-разработка
#
#           Дата.заполнения                                         User.Agent  \
# 0     12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1     12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2     12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3     12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4     12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# ...                   ...                                                ...
# 8699  12/07/2017 15:45:24  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8700  12/07/2017 17:00:06  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8701  12/07/2017 17:32:26  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8702  12/07/2017 18:14:59  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 8703  12/07/2017 21:28:57  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
#
#        exp current_job_exp salary Валюта  cls
# 0      0.5             0.5    400    NaN   QA
# 1      0.0             0.0    430    NaN   QA
# 2      4.0             1.0   2500    NaN  DEV
# 3      5.0             4.0   2000    NaN  DEV
# 4     10.0             0.5   4500    NaN  DEV
# ...    ...             ...    ...    ...  ...
# 8699   1.0             0.0    700    NaN   QA
# 8700   0.5             0.5    400    NaN  NaN
# 8701   1.0             0.5    800    NaN  DEV
# 8702   6.0             4.0   2600    NaN   PM
# 8703   7.0             2.0   5000    NaN  DEV
#
# [8704 rows x 25 columns]
# C:\Users\evgen\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\evgen\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\evgen\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Встановлюємо директиву для побудови графіків всередині Jupyter Notebook
# %matplotlib inline

# Завантажуємо дані з CSV файлу
file_path = r'f:\Dell\Data_Science\HW_DS_2\2\2017_jun_final.csv'
df = pd.read_csv(file_path)

# Побудова графіку
plt.figure(figsize=(10, 6))
plt.hist(df["Зарплата.в.месяц"], bins=20, color='skyblue')
plt.title('Розподіл середньої зарплати на місяць')
plt.xlabel('Середня зарплата (грн)')
plt.ylabel('Кількість працівників')
plt.grid(True)
plt.tight_layout()

average_salary = df["Зарплата.в.месяц"].mean()
print("Средняя зарплата: {:.2f} грн".format(average_salary))

# Выполняем агрегацию данных для минимальной и максимальной зарплаты по должности
aggregated_data = df.groupby("Должность")["Зарплата.в.месяц"].agg(['min', 'max', 'mean'])

# Выводим полученный DataFrame
print(aggregated_data)

# Відображення графіку
plt.show()

# Построение диаграммы средней зарплаты по профессиям
plt.figure(figsize=(12, 6))
plt.bar(aggregated_data.index, aggregated_data["mean"], color='skyblue')
plt.title('Средняя зарплата по профессиям')
plt.xlabel('Профессия')
plt.ylabel('Средняя зарплата (грн)')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()

# Відображення графіку
plt.show()


# Рассчитываем среднюю зарплату и сохраняем её в новом столбце "mean"
df["mean"] = df["Зарплата.в.месяц"].mean()

# Создаем описательную статистику для нового столбца "mean"
description_mean = df["mean"].describe()

# Выводим описательную статистику
print(description_mean)
# Out:
# Средняя зарплата: 1666.70 грн
#                                              min    max         mean
# Должность
# Business analyst                             200   5000  1551.500000
# DBA                                          380   6000  1653.269231
# Data Scientist / Data Analyst                150   8000  1544.240506
# Designer                                     100   4000  1134.161435
# DevOps                                       194  10000  2162.688235
# Director of Engineering / Program Director  1500  34000  5066.363636
# ERP / CRM                                    100   6000  1370.833333
# Game designer                                150   6800  1455.277778
# HR                                           100   7000   850.283401
# HTML coder                                   154   3000   550.993590
# Junior QA engineer                            96   2000   482.774752
# Junior Software Engineer                      75   2600   605.658594
# Marketing                                    100   4000   861.282609
# Product Manager                              250   5000  2054.471264
# Project manager                              190   8000  1512.846361
# QA Tech Lead                                 430   6000  2684.430380
# QA engineer                                  150   2900  1176.704607
# Research Engineer                            114   4000  1099.000000
# Sales manager                                120   2300   635.847059
# Scrum Master                                 370   4500  2355.684211
# Security Specialist                          300   4000  1783.250000
# Senior Project Manager / Program Manager     200   9100  3562.181818
# Senior QA engineer                           400   6000  2385.536122
# Senior Software Engineer                     350   9200  3243.200926
# Software Engineer                            100   7000  1678.630074
# Support                                      138   3650   817.339130
# Sysadmin                                      90   3000   773.542636
# System Architect                             400  10000  4387.076923
# Talent Researcher                            100   1700   550.555556
# Team lead                                    300   7000  2836.328947
# Technical Lead                               500  18000  3664.272000
# Technical writer                             200   3000  1127.892857
# count    8704.000000
# mean     1666.704159
# std         0.000000
# min      1666.704159
# 25%      1666.704159
# 50%      1666.704159
# 75%      1666.704159
# max      1666.704159
# Name: mean, dtype: float64

# %%
# Сохраняем таблицу в CSV файл
output_file_path = r'f:\Dell\Data_Science\HW_DS_2\2\Part_2_resalt.csv'  
df.to_csv(output_file_path, index=False)
